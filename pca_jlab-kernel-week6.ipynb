# %%
import mpld3
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
from sklearn.decomposition import PCA
from astropy.table import Table

# %%
# helpers
def flagOn(value, flag):
    return (value & flag) == flag

# %%
# Create a dataset of all the lightcurves in s0017/0000/0000/0561
sample = []
labels = []
for path in glob('/srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/*/*.fits'):
    print(path)
    fits_file = fits.open(path)
    dat = Table.read(fits_file)
    pd = dat.to_pandas()
    print(pd.shape)
    # Filter out the points where bit 13 (2^12 = 4096) of the quality flag is on
    pd = pd[~flagOn(pd['QUALITY'], 4096)]
    print(pd.shape)
    
    sample.append(pd['SAP_FLUX'])
    labels.append(fits_file[0].header['OBJECT'])
# Out:
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5261/hlsp_qlp_tess_ffi_s0017-0000000005615261_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4864/hlsp_qlp_tess_ffi_s0017-0000000005614864_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4557/hlsp_qlp_tess_ffi_s0017-0000000005614557_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4201/hlsp_qlp_tess_ffi_s0017-0000000005614201_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5021/hlsp_qlp_tess_ffi_s0017-0000000005615021_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4382/hlsp_qlp_tess_ffi_s0017-0000000005614382_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4777/hlsp_qlp_tess_ffi_s0017-0000000005614777_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4986/hlsp_qlp_tess_ffi_s0017-0000000005614986_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4670/hlsp_qlp_tess_ffi_s0017-0000000005614670_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4392/hlsp_qlp_tess_ffi_s0017-0000000005614392_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4808/hlsp_qlp_tess_ffi_s0017-0000000005614808_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4920/hlsp_qlp_tess_ffi_s0017-0000000005614920_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5076/hlsp_qlp_tess_ffi_s0017-0000000005615076_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5311/hlsp_qlp_tess_ffi_s0017-0000000005615311_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4459/hlsp_qlp_tess_ffi_s0017-0000000005614459_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4396/hlsp_qlp_tess_ffi_s0017-0000000005614396_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4261/hlsp_qlp_tess_ffi_s0017-0000000005614261_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4142/hlsp_qlp_tess_ffi_s0017-0000000005614142_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5288/hlsp_qlp_tess_ffi_s0017-0000000005615288_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4504/hlsp_qlp_tess_ffi_s0017-0000000005614504_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4800/hlsp_qlp_tess_ffi_s0017-0000000005614800_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5164/hlsp_qlp_tess_ffi_s0017-0000000005615164_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4250/hlsp_qlp_tess_ffi_s0017-0000000005614250_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5271/hlsp_qlp_tess_ffi_s0017-0000000005615271_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4795/hlsp_qlp_tess_ffi_s0017-0000000005614795_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5270/hlsp_qlp_tess_ffi_s0017-0000000005615270_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4759/hlsp_qlp_tess_ffi_s0017-0000000005614759_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4198/hlsp_qlp_tess_ffi_s0017-0000000005614198_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5394/hlsp_qlp_tess_ffi_s0017-0000000005615394_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4806/hlsp_qlp_tess_ffi_s0017-0000000005614806_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5304/hlsp_qlp_tess_ffi_s0017-0000000005615304_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4784/hlsp_qlp_tess_ffi_s0017-0000000005614784_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4218/hlsp_qlp_tess_ffi_s0017-0000000005614218_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4371/hlsp_qlp_tess_ffi_s0017-0000000005614371_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4792/hlsp_qlp_tess_ffi_s0017-0000000005614792_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4832/hlsp_qlp_tess_ffi_s0017-0000000005614832_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5221/hlsp_qlp_tess_ffi_s0017-0000000005615221_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4588/hlsp_qlp_tess_ffi_s0017-0000000005614588_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4736/hlsp_qlp_tess_ffi_s0017-0000000005614736_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4024/hlsp_qlp_tess_ffi_s0017-0000000005614024_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4756/hlsp_qlp_tess_ffi_s0017-0000000005614756_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/
tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4988/hlsp_qlp_tess_ffi_s0017-0000000005614988_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4573/hlsp_qlp_tess_ffi_s0017-0000000005614573_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4414/hlsp_qlp_tess_ffi_s0017-0000000005614414_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5395/hlsp_qlp_tess_ffi_s0017-0000000005615395_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4972/hlsp_qlp_tess_ffi_s0017-0000000005614972_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4925/hlsp_qlp_tess_ffi_s0017-0000000005614925_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5106/hlsp_qlp_tess_ffi_s0017-0000000005615106_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5454/hlsp_qlp_tess_ffi_s0017-0000000005615454_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4999/hlsp_qlp_tess_ffi_s0017-0000000005614999_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4520/hlsp_qlp_tess_ffi_s0017-0000000005614520_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5259/hlsp_qlp_tess_ffi_s0017-0000000005615259_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5058/hlsp_qlp_tess_ffi_s0017-0000000005615058_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5061/hlsp_qlp_tess_ffi_s0017-0000000005615061_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5110/hlsp_qlp_tess_ffi_s0017-0000000005615110_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5060/hlsp_qlp_tess_ffi_s0017-0000000005615060_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4273/hlsp_qlp_tess_ffi_s0017-0000000005614273_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4858/hlsp_qlp_tess_ffi_s0017-0000000005614858_tess_v01_llc.fits
# (1130, 13)
# (716, 13)
# /srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4979/hlsp_qlp_tess_ffi_s0017-0000000005614979_tess_v01_llc.fits
# (1130, 13)
# (716, 13)

# %%
len(labels)
# Out:
# 110

# %%
from sklearn.impute import SimpleImputer
imp_constant = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value=1)
imputed_sample = imp_constant.fit_transform(sample)

# %%
pca = PCA(n_components=2)
sample_after_pca = pca.fit(imputed_sample).transform(imputed_sample)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.6962792 , 0.16816653], dtype=float32)

# %%
fig = plt.figure()
scatter = plt.scatter(
    sample_after_pca[:, 0], sample_after_pca[:, 1], s=5, label=labels
)

plt.title("PCA of lightcurves in s0017/0000/0000/0561")

tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=labels)
mpld3.plugins.connect(fig, tooltip)

mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el31782477831815335206716186374"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el31782477831815335206716186374", {"width": 432.0, "height": 288.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [-1.5074646280260953, 15.377475600049102], "ylim": [-1.7928088058680018, 5.5970207800119836], "xdomain": [-1.5074646280260953, 15.377475600049102], "ydomain": [-1.7928088058680018, 5.5970207800119836], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 10, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 9, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el3178247783181533392", "lines": [], "paths": [], "markers": [], "texts": [{"text": "PCA of lightcurves in s0017/0000/0000/0561", "position": [0.49999999999999994, 1.0275938189845473], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "auto", "rotation": -0.0, "fontsize": 12.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el3178247783197212304"}], "collections": [{"offsets": "data01", "xindex": 0, "yindex": 1, "paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "pathtransforms": [[2.23606797749979, 0.0, 0.0, 2.23606797749979, 0.0, 0.0]], "alphas": [null], "edgecolors": ["#1F77B4"], "facecolors": ["#1F77B4"], "edgewidths": [1.0], "offsetcoordinates": "data", "pathcoordinates": "display", "zorder": 1, "id": "el3178247783197323216"}], "images": [], "sharex": [], "sharey": []}], "data": {"data01": [[-0.20475956797599792, -0.16736361384391785], [-0.24414873123168945, -0.20931105315685272], [0.9210761785507202, 1.2111756801605225], [-0.27116718888282776, -0.2039104402065277], [0.5846256613731384, 1.0596566200256348], [-0.24523988366127014, -0.2094859480857849], [-0.20252199470996857, -0.1845194697380066], [-0.22430895268917084, -0.19763658940792084], [-0.2656315863132477, -0.2215111404657364], [-0.24541011452674866, -0.22391250729560852], [-0.2328038513660431, -0.2078399807214737], [-0.26026999950408936, -0.17272308468818665], [-0.20567885041236877, -0.18950530886650085], [-0.1964566856622696, -0.14084666967391968], [-0.24959136545658112, -0.20039381086826324], [-0.264673113822937, -0.21491409838199615], [-0.229524165391922, -0.20882973074913025], [-0.47125840187072754, -0.28962308168411255], [-0.19968175888061523, -0.1348738670349121], [-0.25857987999916077, -0.15222878754138947], [-0.2601795494556427, -0.24851056933403015], [-0.1309993416070938, -0.2602910101413727], [-0.23260368406772614, -0.19685840606689453], [-0.2471148818731308, -0.2051365077495575], [-0.2036358118057251, -0.19727952778339386], [-0.19339382648468018, -0.1426561027765274], [-0.23432928323745728, -0.20026624202728271], [-0.2457585334777832, -0.2261500358581543], [-0.5819088816642761, 0.8075233697891235], [-0.22174502909183502, -0.18453413248062134], [-0.24153795838356018, -0.21020367741584778], [-0.2416282743215561, -0.17136305570602417], [-0.14950144290924072, 0.03274920582771301], [-0.22662323713302612, -0.19851087033748627], [-0.30091196298599243, -0.328681498 ...

# %% [markdown]
# Outliers are:
# * (bottom right) TIC 5614834 https://exofop.ipac.caltech.edu/tess/target.php?id=5615395
# * (top left) TIC 5615053 https://exofop.ipac.caltech.edu/tess/target.php?id=5615165

# %%
rando = fits.open('/srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4834/hlsp_qlp_tess_ffi_s0017-0000000005614834_tess_v01_llc.fits')
dat = Table.read(rando)
pd = dat.to_pandas()
pd.shape
pd = pd[~flagOn(pd['QUALITY'], 4096)]
pd.shape

plt.figure(figsize=(15,2))
sf = pd['SAP_FLUX'].tolist()
t = pd['TIME'].tolist()

plt.plot(t, sf, '.')
plt.ylim(0, 3.4)
# Out:
# (0, 3.4)

# %%
rando = fits.open('/srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5053/hlsp_qlp_tess_ffi_s0017-0000000005615053_tess_v01_llc.fits')
dat = Table.read(rando)
pd = dat.to_pandas()
pd = pd[~flagOn(pd['QUALITY'], 4096) & ~flagOn(pd['QUALITY'], 2048)]

plt.figure(figsize=(15,2))
sf = pd['SAP_FLUX'].tolist()
t = pd['TIME'].tolist()

plt.plot(t, sf, '.')
plt.ylim(-0.2, 2)
# Out:
# (-0.2, 2)

# %%
i = labels.index('TIC 5615053')

sf = imputed_sample[i].tolist()

rando = fits.open('/srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5053/hlsp_qlp_tess_ffi_s0017-0000000005615053_tess_v01_llc.fits')
dat = Table.read(rando)
pd = dat.to_pandas()
pd = pd[~flagOn(pd['QUALITY'], 4096)]
t = pd['TIME'].tolist()

plt.figure(figsize=(15,2))
plt.plot(t, sf, '.')
plt.ylim(-0.2, 2)
# Out:
# (-0.2, 2)

# %%
rando = fits.open('/srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/4132/hlsp_qlp_tess_ffi_s0017-0000000005614132_tess_v01_llc.fits')
dat = Table.read(rando)
pd = dat.to_pandas()
pd = pd[~flagOn(pd['QUALITY'], 4096)]

plt.figure(figsize=(15,2))
sf = pd['SAP_FLUX'].tolist()
t = pd['TIME'].tolist()

plt.plot(t, sf, '.')
plt.ylim(0.8, 1.2)
# Out:
# (0.8, 1.2)

# %%
rando = fits.open('/srv/scratch/astro/z3529659/qlp/s0017/0000/0000/0561/5454/hlsp_qlp_tess_ffi_s0017-0000000005615454_tess_v01_llc.fits')
dat = Table.read(rando)
pd = dat.to_pandas()
pd = pd[~flagOn(pd['QUALITY'], 4096)]

plt.figure(figsize=(15,2))
sf = pd['SAP_FLUX'].tolist()
t = pd['TIME'].tolist()

plt.plot(t, sf, '.')
plt.ylim(0.95, 1.05)
# Out:
# (0.95, 1.05)
